# %% [markdown]
# # Getting Started With Machine Learning #

# %% [markdown]
# ## 02 – NumPy
#
# **Abstract**
# <br>
# This notebook teaches the basics of the Numerical Python (NumPy) package.

# %% [markdown]
# ## Numerical Python ##
#
# NumPy is a package that provides tools and techniques for manipulating data structures with arrays. It's far superior to Python's lists, offering faster access and write speeds. It boasts a comprehensive collection of tools and techniques that can be used to solve mathematical problems, and it also contains all the necessary functions for working with arrays.
#
# * Numeric Python
# * Alternative to Python List: NumPy Array
# * Calculations over entire arrays
# * Easy and Fasy
# * Installation
#     * In the terminal: ```python -m pip install numpy```

# %%
# DO NOT CHANGE THIS CELL
import numpy as np

# %% [markdown]
# We have some information from a sample with:
# * Height
# * Weight

# %%
# DO NOT CHANGE THIS CELL
height = [1.73, 1.68, 1.71, 1.89, 1.79]
weight = [65.4, 59.2, 63.6, 88.4, 68.7]

# %% [markdown]
# Now, we can to calculate the ibm of each person, but something happen

# %%
# DO NOT CHANGE THIS CELL
np_weight / np_height ** 2

# %% [markdown]
# Thats why python list can could do this type of calculations, for this porpouse existe python

# %% [markdown]
# Now convert the python list into numpy arrays

# %%
np_height = np.array(height)
np_height

# %%
np_weight = np.array(weight)
np_height

# %% [markdown]
# Try to calculate again the bmi

# %%
bmi = np_weight / np_height ** 2
bmi

# %% [markdown]
# Now its works

# %% [markdown]
# Now we need to see some remarks about numpy

# %%
python_list = [1, 2, 3]
numpy_array = np.array([1, 2, 3])

# %%
python_list + python_list

# %%
numpy_array + numpy_array

# %%
bmi

# %%
bmi[1]

# %%
bmi > 23

# %%
bmi[bmi > 23]

# %%
type(np_height)

# %%
type(np_weight)

# %%
np_2d = np.array([[1.73, 1.68, 1.71, 1.89, 1.79],
                  [65.4, 59.2, 63.6, 88.4, 68.7]])
np_2d

# %%
np_2d.shape

# %%
np_2d[0]

# %%
np_2d[0][2]

# %%
np_2d[0, 2]

# %%
np_2d[:, 1:3]

# %%
np_2d[1, :]

# %% [markdown]
# <details>
# <summary>Click ... for solution.</summary>
#
# Aquí va la solución completa
# puede ser texto, ecuaciones, código, etc.
#
# ```python
# print("Hello world")
